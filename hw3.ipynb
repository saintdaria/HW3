# %%
import random
import numpy as np
import matplotlib.pyplot as plt
plt.figure(figsize=(16,8))
p = 0.51

def A(outcome,j):
    random.seed(j)
    if random.random() < (p):
        return outcome + 1
    else:
        return outcome - 1




def fun(numIter, numFlip, gameF,p):
    npOutcome = np.zeros((numIter, numFlip))
    for i in range(numIter):
        outcome = []
        tmp = 0
        k = 0
        for j in range(numFlip):
            if
            p += 5
            j = j*6
            tmp = gameF(tmp,j)
            outcome.append(tmp)
        npOutcome[i, :] = outcome
    return np.mean(npOutcome, 0)


numIter = 10
numFlip = 8000

resultA = fun(numIter, numFlip, A, 0.49)

my_list = list(resultA)
new_list = [x+3 for x in my_list]
resultA = np.array(new_list)
plt.plot(resultA)
plt.show()
